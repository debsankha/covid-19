# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Cases-in-each-state" data-toc-modified-id="Cases-in-each-state-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Cases in each state</a></div><div class="lev3 toc-item"><a href="#Download-population-densities" data-toc-modified-id="Download-population-densities-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Download population densities</a></div><div class="lev1 toc-item"><a href="#Deaths" data-toc-modified-id="Deaths-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Deaths</a></div><div class="lev2 toc-item"><a href="#get-all-the-states-in-a-single-DF" data-toc-modified-id="get-all-the-states-in-a-single-DF-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>get all the states in a single DF</a></div><div class="lev3 toc-item"><a href="#Bugfix" data-toc-modified-id="Bugfix-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Bugfix</a></div><div class="lev2 toc-item"><a href="#Hospitals" data-toc-modified-id="Hospitals-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Hospitals</a></div><div class="lev4 toc-item"><a href="#From-veronica" data-toc-modified-id="From-veronica-2.2.0.1"><span class="toc-item-num">2.2.0.1&nbsp;&nbsp;</span>From veronica</a></div>

# %%
# %matplotlib inline
import matplotlib

matplotlib.rcParams['font.size'] = 15

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Main data source:
# https://npgeo-corona-npgeo-de.hub.arcgis.com/datasets/dd4580c810204019a7b8eb3e0b329dd6_0/data

# %%
url = "https://opendata.arcgis.com/datasets/dd4580c810204019a7b8eb3e0b329dd6_0.csv"

df = pd.read_csv(url)
df
# Out:
#       IdBundesland          Bundesland     Landkreis Altersgruppe Geschlecht  \
# 0                1  Schleswig-Holstein  SK Flensburg      A15-A34          M
# 1                1  Schleswig-Holstein  SK Flensburg      A15-A34          M
# 2                1  Schleswig-Holstein  SK Flensburg      A15-A34          M
# 3                1  Schleswig-Holstein  SK Flensburg      A15-A34          W
# 4                1  Schleswig-Holstein  SK Flensburg      A15-A34          W
# ...            ...                 ...           ...          ...        ...
# 8914             8   Baden-Württemberg   LK Rottweil      A15-A34          W
# 8915             8   Baden-Württemberg   LK Rottweil      A15-A34          W
# 8916             8   Baden-Württemberg   LK Rottweil      A35-A59          M
# 8917             8   Baden-Württemberg   LK Rottweil      A35-A59          W
# 8918             8   Baden-Württemberg   LK Rottweil      A60-A79          M
#
#       AnzahlFall  AnzahlTodesfall  ObjectId                Meldedatum  \
# 0              1                0    163400  2020-03-14T00:00:00.000Z
# 1              2                0    163401  2020-03-19T00:00:00.000Z
# 2              1                0    163402  2020-03-21T00:00:00.000Z
# 3              1                0    163403  2020-03-14T00:00:00.000Z
# 4              2                0    163404  2020-03-18T00:00:00.000Z
# ...          ...              ...       ...                       ...
# 8914           1                0    168395  2020-03-13T00:00:00.000Z
# 8915           1                0    168396  2020-03-18T00:00:00.000Z
# 8916           1                0    168397  2020-03-20T00:00:00.000Z
# 8917           1                0    168398  2020-03-20T00:00:00.000Z
# 8918           1                0    168399  2020-03-18T00:00:00.000Z
#
#       IdLandkreis        Datenstand
# 0            1001  22.03.2020 00:00
# 1            1001  22.03.2020 00:00
# 2            1001  22.03.2020 00:00
# 3            1001  22.03.2020 00:00
# 4            1001  22.03.2020 00:00
# ...           ...               ...
# 8914         8325  22.03.2020 00:00
# 8915         8325  22.03.2020 00:00
# 8916         8325  22.03.2020 00:00
# 8917         8325  22.03.2020 00:00
# 8918         8325  22.03.2020 00:00
#
# [8919 rows x 11 columns]

# %%
df['Meldedatum'] = pd.to_datetime(df["Meldedatum"])

# %%
df.sort_values(by='Meldedatum')
# Out:
#       IdBundesland       Bundesland             Landkreis Altersgruppe  \
# 3847             9           Bayern   LK Landsberg a.Lech      A15-A34
# 6012             9           Bayern          LK Starnberg      A35-A59
# 3801             9           Bayern   LK Fürstenfeldbruck      A15-A34
# 3492             9           Bayern            SK München      A15-A34
# 6048             9           Bayern         LK Traunstein      A00-A04
# ...            ...              ...                   ...          ...
# 6408             9           Bayern    SK Weiden i.d.OPf.      A15-A34
# 7663             7  Rheinland-Pfalz       LK Mainz-Bingen      A15-A34
# 3787             9           Bayern           LK Freising         A80+
# 6633             9           Bayern             LK Coburg      A35-A59
# 6378             9           Bayern  LK Dingolfing-Landau      A35-A59
#
#      Geschlecht  AnzahlFall  AnzahlTodesfall  ObjectId  \
# 3847          M           1                0    169247
# 6012          M           1                0    169493
# 3801          M           1                0    169201
# 3492          W           1                0    168892
# 6048          W           1                0    169529
# ...         ...         ...              ...       ...
# 6408          M           1                0    169889
# 7663          W           1                0    167144
# 3787          M           1                0    169187
# 6633          W           2                0    170114
# 6378          W           2                0    169859
#
#                     Meldedatum  IdLandkreis        Datenstand
# 3847 2020-01-28 00:00:00+00:00         9181  22.03.2020 00:00
# 6012 2020-01-28 00:00:00+00:00         9188  22.03.2020 00:00
# 3801 2020-01-29 00:00:00+00:00         9179  22.03.2020 00:00
# 3492 2020-01-29 00:00:00+00:00         9162  22.03.2020 00:00
# 6048 2020-01-31 00:00:00+00:00         9189  22.03.2020 00:00
# ...                        ...          ...               ...
# 6408 2020-03-21 00:00:00+00:00         9363  22.03.2020 00:00
# 7663 2020-03-21 00:00:00+00:00         7339  22.03.2020 00:00
# 3787 2020-03-21 00:00:00+00:00         9178  22.03.2020 00:00
# 6633 2020-03-21 00:00:00+00:00         9473  22.03.2020 00:00
# 6378 2020-03-21 00:00:00+00:00         9279  22.03.2020 00:00
#
# [8919 rows x 11 columns]

# %%
##

# %%
df['Altersgruppe'].unique()
# Out:
# array(['A15-A34', 'A35-A59', 'A60-A79', 'unbekannt', 'A00-A04', 'A05-A14',
#        'A80+'], dtype=object)

# %%
nie = df[df['Bundesland']=='Niedersachsen'][['Meldedatum', 'AnzahlFall']]
nie
# Out:
#                     Meldedatum  AnzahlFall
# 372  2020-03-19 00:00:00+00:00           1
# 373  2020-03-20 00:00:00+00:00           1
# 374  2020-03-05 00:00:00+00:00           1
# 375  2020-03-19 00:00:00+00:00           1
# 376  2020-03-20 00:00:00+00:00           3
# ...                        ...         ...
# 1145 2020-03-18 00:00:00+00:00           1
# 1146 2020-03-19 00:00:00+00:00           1
# 1147 2020-03-11 00:00:00+00:00           1
# 1148 2020-03-14 00:00:00+00:00           2
# 1149 2020-03-18 00:00:00+00:00           1
#
# [778 rows x 2 columns]

# %%
nie['date'] = nie['Meldedatum'].apply(lambda x:x.date())
nie
# Out:
#                     Meldedatum  AnzahlFall        date
# 372  2020-03-19 00:00:00+00:00           1  2020-03-19
# 373  2020-03-20 00:00:00+00:00           1  2020-03-20
# 374  2020-03-05 00:00:00+00:00           1  2020-03-05
# 375  2020-03-19 00:00:00+00:00           1  2020-03-19
# 376  2020-03-20 00:00:00+00:00           3  2020-03-20
# ...                        ...         ...         ...
# 1145 2020-03-18 00:00:00+00:00           1  2020-03-18
# 1146 2020-03-19 00:00:00+00:00           1  2020-03-19
# 1147 2020-03-11 00:00:00+00:00           1  2020-03-11
# 1148 2020-03-14 00:00:00+00:00           2  2020-03-14
# 1149 2020-03-18 00:00:00+00:00           1  2020-03-18
#
# [778 rows x 3 columns]

# %%
case_ts = nie[['date', 'AnzahlFall']].groupby('date').agg('sum')
case_ts['cumulative'] = case_ts['AnzahlFall'].cumsum()
case_ts
# Out:
#             AnzahlFall  cumulative
# date
# 2020-02-04           1           1
# 2020-03-01           1           2
# 2020-03-02           1           3
# 2020-03-03           6           9
# 2020-03-04           3          12
# 2020-03-05           5          17
# 2020-03-06           8          25
# 2020-03-07           7          32
# 2020-03-08           3          35
# 2020-03-09          16          51
# 2020-03-10          34          85
# 2020-03-11          52         137
# 2020-03-12          65         202
# 2020-03-13          81         283
# 2020-03-14          59         342
# 2020-03-15          49         391
# 2020-03-16         128         519
# 2020-03-17         141         660
# 2020-03-18         217         877
# 2020-03-19         187        1064
# 2020-03-20         215        1279
# 2020-03-21          27        1306

# %%
import seaborn as sns

# %%
import numpy as np

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,4))

case_ts['cumulative'].plot(ax=ax1)

thres = 50
thres_crossing_date = case_ts[case_ts['cumulative'] > 50].iloc[0].name
case_ts['day_since_thres'] = case_ts.index - thres_crossing_date

sns.lineplot(x='day_since_thres', y='cumulative', estimator=None, data=case_ts)
day_min = 0
day_max = case_ts['day_since_thres'].max()/pd.Timedelta(days=1)

ax2.set_xlim(0, day_max*24*3600*1000)

xtick_days = np.arange(0, day_max, 5)
xticks = [day*24*3600*1000 for day in xtick_days]
xticklabels = [str(d) for d in xtick_days]

ax2.set_xticks(xticks)
ax2.set_xticklabels(xticklabels)
# Out:
# [Text(0, 0, '0.0'), Text(0, 0, '5.0'), Text(0, 0, '10.0')]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,4))

case_ts['cumulative'].plot(ax=ax1)
ax1.tick_params(axis='x', labelrotation=45)


thres = 50
thres_crossing_date = case_ts[case_ts['cumulative'] > 50].iloc[0].name
case_ts['day_since_thres'] = (case_ts.index - thres_crossing_date)/pd.Timedelta(days=1)

sns.lineplot(x='day_since_thres', y='cumulative', estimator=None, data=case_ts, ax=ax2)
xmin, xmax = ax2.get_xlim()
ax2.set_xlim(0, xmax)
# Out:
# (0.0, 14.3)

# %% [markdown]
# # Cases in each state

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18,7))

day_max = 0

for bundesland in df['Bundesland'].unique():
    df_state = df[df['Bundesland']==bundesland][['Meldedatum', 'AnzahlFall']]
    df_state['date'] = df_state['Meldedatum'].apply(lambda x:x.date())
    case_ts = df_state[['date', 'AnzahlFall']].groupby('date').agg('sum')
    case_ts['cumulative'] = case_ts['AnzahlFall'].cumsum()

    case_ts['cumulative'].plot(ax=ax1, label=bundesland[:4])
    ax1.tick_params(axis='x', labelrotation=45)


    thres = 50
    if len(case_ts[case_ts['cumulative'] > 50]) == 0:
        continue
    thres_crossing_date = case_ts[case_ts['cumulative'] > 50].iloc[0].name
    case_ts['day_since_thres'] = (case_ts.index - thres_crossing_date)/pd.Timedelta(days=1)

    sns.lineplot(x='day_since_thres', y='cumulative', estimator=None, data=case_ts, ax=ax2, label=bundesland[:4])
    
ax2.set_xlim(0, ax2.get_xlim()[1])
ax1.legend()
ax2.legend()

ax2.set_xlabel("days since 50 cases")
ax2.set_ylabel("cases")

ax2.set_yscale('log')
ax1.set_yscale('log')

# %% [markdown]
# ### Download population densities

# %%
# !pip install bs4
# Out:
# Requirement already satisfied: bs4 in ./venv/lib/python3.6/site-packages
# Requirement already satisfied: beautifulsoup4 in ./venv/lib/python3.6/site-packages (from bs4)
# Requirement already satisfied: soupsieve>=1.2 in ./venv/lib/python3.6/site-packages (from beautifulsoup4->bs4)

# %%
import pandas as pd

# %%
tables = pd.read_html("https://de.wikipedia.org/wiki/Liste_der_deutschen_Bundesl%C3%A4nder_nach_Bev%C3%B6lkerung", thousands='.')
tables[0]
# Out:
#                 Bundesland        1960        1970        1980      1990  \
# 0        Baden-Württemberg   7726859.0   8953607.0   9258947.0   9822027
# 1                   Bayern   9494939.0  10561110.0  10928151.0  11448823
# 2                Berlin[1]   2202241.0   2115311.0   1896230.0   3433695
# 3              Brandenburg         NaN         NaN         NaN   2578312
# 4                   Bremen    704287.0    735452.0    693846.0    681665
# 5                  Hamburg   1836958.0   1793640.0   1645095.0   1652363
# 6                   Hessen   4783352.0   5424529.0   5601031.0   5763310
# 7   Mecklenburg-Vorpommern         NaN         NaN         NaN   1923959
# 8            Niedersachsen   6576137.0   7121824.0   7256386.0   7387245
# 9      Nordrhein-Westfalen  15852476.0  17004851.0  17058193.0  17349651
# 10         Rheinland-Pfalz   3411170.0   3658932.0   3642482.0   3763510
# 11                Saarland   1060493.0   1121300.0   1066299.0   1072963
# 12                 Sachsen         NaN         NaN         NaN   4764301
# 13          Sachsen-Anhalt         NaN         NaN         NaN   2873957
# 14      Schleswig-Holstein   2309409.0   2510608.0   2611285.0   2626127
# 15               Thüringen         NaN         NaN         NaN   2611319
# 16          Deutschland[2]  55958321.0  61001164.0  61657945.0  79753227
#
#         2000      2010      2015      2018
# 0   10524415  10753880  10879618  11069533
# 1   12230255  12538696  12843514  13076721
# 2    3382169   3460725   3520031   3644826
# 3    2601962   2503273   2484826   2511917
# 4     660225    660706    671489    682986
# 5    1715392   1786448   1787408   1841179
# 6    6068129   6067021   6176172   6265809
# 7    1775703   1642327   1612362   1609675
# 8    7926193   7918293   7926599   7982448
# 9   18009865  17845154  17865516  17932651
# 10   4034557   4003745   4052803   4084844
# 11   1068703   1017567    995597    990509
# 12   4425581   4149477   4084851   4077937
# 13   2615375   2335006   2245470   2208321
# 14   2789761   2834259   2858714   2896712
# 15   2431255   2235025   2170714   2143145
# 16  82259540  81751602  82175684  83019213

# %%
population_states = tables[0][['Bundesland', '2018']]
population_states.head()
# Out:
#           Bundesland      2018
# 0  Baden-Württemberg  11069533
# 1             Bayern  13076721
# 2          Berlin[1]   3644826
# 3        Brandenburg   2511917
# 4             Bremen    682986

# %%
population_states.loc[2, 'Bundesland'] = 'Berlin'
population_states.loc[16, 'Bundesland'] = 'Germany'
# Out:
# /home/dmanik/covid-19/venv/lib/python3.6/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
population_states
# Out:
#                 Bundesland      2018
# 0        Baden-Württemberg  11069533
# 1                   Bayern  13076721
# 2                   Berlin   3644826
# 3              Brandenburg   2511917
# 4                   Bremen    682986
# 5                  Hamburg   1841179
# 6                   Hessen   6265809
# 7   Mecklenburg-Vorpommern   1609675
# 8            Niedersachsen   7982448
# 9      Nordrhein-Westfalen  17932651
# 10         Rheinland-Pfalz   4084844
# 11                Saarland    990509
# 12                 Sachsen   4077937
# 13          Sachsen-Anhalt   2208321
# 14      Schleswig-Holstein   2896712
# 15               Thüringen   2143145
# 16                 Germany  83019213

# %%
population_states
# Out:
#                 Bundesland      2018
# 0        Baden-Württemberg  11069533
# 1                   Bayern  13076721
# 2                   Berlin   3644826
# 3              Brandenburg   2511917
# 4                   Bremen    682986
# 5                  Hamburg   1841179
# 6                   Hessen   6265809
# 7   Mecklenburg-Vorpommern   1609675
# 8            Niedersachsen   7982448
# 9      Nordrhein-Westfalen  17932651
# 10         Rheinland-Pfalz   4084844
# 11                Saarland    990509
# 12                 Sachsen   4077937
# 13          Sachsen-Anhalt   2208321
# 14      Schleswig-Holstein   2896712
# 15               Thüringen   2143145
# 16                 Germany  83019213

# %%
day_max = 0

with sns.color_palette("husl"):
    fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18,7))
    
    case_thres = 50

    for bundesland in list(df['Bundesland'].unique()) + ['Germany']:
        # get population
        try:
            pop = population_states[population_states['Bundesland']==bundesland].values[0,1]
        except:
            print(f"Population for {bundesland} not found")
            continue
                    
        if bundesland == 'Germany':
            label='Germany'
            df_state = df[['Meldedatum', 'AnzahlFall']]
        else:
            df_state = df[df['Bundesland']==bundesland][['Meldedatum', 'AnzahlFall']]
            label = bundesland[:4]
            
        df_state['date'] = df_state['Meldedatum'].apply(lambda x:x.date())
        df_state.sort_values(by='date')

        case_ts = df_state[['date', 'AnzahlFall']].groupby('date').agg('sum')
        case_ts['cumulative'] = case_ts['AnzahlFall'].cumsum()
        case_ts['cumulative_normed'] = case_ts['cumulative']/pop*100000

        case_ts['cumulative_normed'].plot(ax=ax1, label=label)
        ax1.tick_params(axis='x', labelrotation=45)


        if len(case_ts[case_ts['cumulative'] > case_thres]) == 0:
            continue
        thres_crossing_date = case_ts[case_ts['cumulative'] > case_thres].iloc[0].name
        case_ts['day_since_thres'] = (case_ts.index - thres_crossing_date)/pd.Timedelta(days=1)

        sns.lineplot(x='day_since_thres', y='cumulative_normed', estimator=None, data=case_ts, ax=ax2, label=label, markers=True, dashes=True)
        
    ax2.set_xlim(0, ax2.get_xlim()[1])
    ax1.legend(fontsize=15, ncol=2)
    ax2.legend(fontsize=15, ncol=2)

    ax2.set_xlabel(f"days since {case_thres} cases reported")
    ax2.set_ylabel("cases/100000 inhabitants")

    ax2.set_yscale('log')
    ax1.set_yscale('log')

fig.tight_layout()

fig.savefig("bundeslaender.pdf")
# Out:
# /home/dmanik/covid-19/venv/lib/python3.6/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # Deaths

# %%
day_max = 0

with sns.color_palette("husl"):
    fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18,7))
    
    for bundesland in list(df['Bundesland'].unique()) + ['Germany']:
        # get population
        try:
            pop = population_states[population_states['Bundesland']==bundesland].values[0,1]
        except:
            print(f"Population for {bundesland} not found")
            continue
                    
        if bundesland == 'Germany':
            label='Germany'
            df_state = df[['Meldedatum', 'AnzahlTodesfall']]
        else:
            df_state = df[df['Bundesland']==bundesland][['Meldedatum', 'AnzahlTodesfall']]
            label = bundesland[:4]
            
        df_state['date'] = df_state['Meldedatum'].apply(lambda x:x.date())
        df_state.sort_values(by='date')
        case_ts = df_state[['date', 'AnzahlTodesfall']].groupby('date').agg('sum')
        case_ts['cumulative'] = case_ts['AnzahlTodesfall'].cumsum()
        case_ts['cumulative_normed'] = case_ts['cumulative']/pop*100000

        case_ts['cumulative_normed'].plot(ax=ax1, label=label)
        ax1.tick_params(axis='x', labelrotation=45)


        if len(case_ts[case_ts['cumulative'] > 0]) == 0:
            print(f"No death in {bundesland}")
            continue
        thres_crossing_date = case_ts[case_ts['cumulative'] > 0].iloc[0].name
        case_ts['day_since_thres'] = (case_ts.index - thres_crossing_date)/pd.Timedelta(days=1)

        sns.lineplot(x='day_since_thres', y='cumulative_normed', estimator=None, data=case_ts, ax=ax2, label=label, markers=True, dashes=True)
        
    ax2.set_xlim(0, ax2.get_xlim()[1])
    ax1.legend(fontsize=15, ncol=2)
    ax2.legend(fontsize=15, ncol=2)

    ax2.set_xlabel(f"days since first death")
    ax2.set_ylabel("deaths/100000 inhabitants")

    ax2.set_yscale('log')
    ax1.set_yscale('log')
    ax1.xaxis.set_tick_params(rotation=45)
fig.tight_layout()

#fig.savefig("bundeslaender.pdf")
# Out:
# No death in Hamburg
# No death in Bremen
# No death in Saarland
# No death in Brandenburg
# No death in Mecklenburg-Vorpommern
# No death in Sachsen
# No death in Sachsen-Anhalt
# No death in Thüringen
# /home/dmanik/covid-19/venv/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## get all the states in a single DF

# %%
 df_state = df[df['Bundesland']==bundesland][['Meldedatum', 'AnzahlFall']]
            label = bundesland[:4]
            
df_state['date'] = df_state['Meldedatum'].apply(lambda x:x.date())
df_state.sort_values(by='date')
# Out:
#   File "<ipython-input-260-3c6bb5ae8459>", line 2
#     label = bundesland[:4]
#     ^
# IndentationError: unexpected indent

# %%
narrow_df = df[['Bundesland', 'AnzahlFall', 'AnzahlTodesfall', 'Meldedatum']]
narrow_df['Meldedatum'] = narrow_df['Meldedatum'].apply(lambda x:x.date())
narrow_df

# %%
narrow_df.sort_values(by='Meldedatum', inplace=True)
cumsum_dfs = []

for bundesland in list(narrow_df['Bundesland'].unique())+['Germany']:
    if bundesland == 'Germany':
        sel = narrow_df
    else:
        sel = narrow_df[narrow_df['Bundesland']==bundesland]
    sel = sel[['Meldedatum','AnzahlFall', 'AnzahlTodesfall']].groupby('Meldedatum').agg('sum')
    sel = sel.sort_values(by='Meldedatum')
    sel['cumulative_cases'] = sel['AnzahlFall'].cumsum()
    sel['cumulative_deaths'] = sel['AnzahlTodesfall'].cumsum()
    
    if len(sel[sel['cumulative_cases'] > 50]) > 0:
        first_case_date = sel[sel['cumulative_cases'] > 50].iloc[0].name
        sel['days_since_50_cases'] = (sel.index - first_case_date)/pd.Timedelta(days=1)
    else:
        sel['days_since_50_cases'] = None
    
    if len(sel[sel['cumulative_deaths'] > 0]) > 0:
        first_death_date = sel[sel['cumulative_deaths'] > 0].iloc[0].name
        sel['days_since_first_death'] = (sel.index - first_death_date)/pd.Timedelta(days=1)
    else:
        sel['days_since_first_death'] = None
    sel['Bundesland'] = bundesland
    
    cumsum_dfs.append(sel.reset_index())

all_cum_df = pd.concat(cumsum_dfs)
all_cum_df

# %%
all_cum_df[all_cum_df['cumulative_deaths']>0].iloc[0]

# %%
# !date

# %%
21-5

# %%
all_cum_df = all_cum_df.merge(population_states, left_on='Bundesland', right_on='Bundesland')
all_cum_df.rename({'2018': 'population'}, axis='columns', inplace=True)
all_cum_df

# %%
all_cum_df['cumulative_deaths_normed'] = all_cum_df['cumulative_deaths']*100000/all_cum_df['population']
all_cum_df['cumulative_cases_normed'] = all_cum_df['cumulative_cases']*100000/all_cum_df['population']

# %%
german_state_abbrs = {
'Baden-Württemberg': 'BW',
'Bayern': 'BY',
'Berlin': 'BE',
'Brandenburg': 'BB',
'Bremen': 'HB',
'Hamburg': 'HH',
'Hessen': 'HE',
'Niedersachsen': 'NI',
'Mecklenburg-Vorpommern': 'MV',
'Nordrhein-Westfalen': 'NW',
'Rheinland-Pfalz': 'RP',
'Saarland': 'SL',
'Sachsen': 'SN',
'Sachsen-Anhalt': 'ST',
'Schleswig-Holstein': 'SH',
'Thüringen': 'TH',
}

# %%
all_cum_df['state'] = all_cum_df['Bundesland'].apply(lambda x:german_state_abbrs[x] if x!='Germany' else 'Germany')
all_cum_df['date'] = all_cum_df['Meldedatum'].apply(lambda x:pd.Timestamp(x))

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18,6))

sns.lineplot(data=all_cum_df, x='Meldedatum', y='cumulative_cases_normed', hue='state', ax=ax1, ci=None)
sns.lineplot(data=all_cum_df, x='days_since_50_cases', y='cumulative_cases_normed', hue='state', ax=ax2, ci=None)

#ax1.set_xlim(0, ax1.get_xlim()[1])
ax2.set_xlim(0, ax2.get_xlim()[1])
ax1.legend(fontsize=10, ncol=2)
ax2.legend(fontsize=10, ncol=2)

ax1.set_ylabel("cases/100000 inhabitants")
ax2.set_xlabel(f"days since 50 cases")
ax2.set_ylabel("cases/100000 inhabitants")

ax1.xaxis.set_tick_params(rotation=45)

ax2.set_yscale('log')
ax1.set_yscale('log')

fig.tight_layout()
fig.savefig("bundeslaender_faelle.pdf")

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18,6))

sns.lineplot(data=all_cum_df, x='Meldedatum', y='cumulative_deaths_normed', hue='state', ax=ax1, ci=None)
sns.lineplot(data=all_cum_df, x='days_since_first_death', y='cumulative_deaths_normed', hue='state', ax=ax2, ci=None)


#ax1.set_xlim(0, ax1.get_xlim()[1])
ax2.set_xlim(0, ax2.get_xlim()[1])
ax1.legend(fontsize=10, ncol=2)
ax2.legend(fontsize=10, ncol=2)


ax1.set_ylabel("deaths/100000 inhabitants")

ax2.set_xlabel(f"days since first death")
ax2.set_ylabel("deaths/100000 inhabitants")

ax1.xaxis.set_tick_params(rotation=45)

ax2.set_yscale('log')
ax1.set_yscale('log')

fig.tight_layout()
fig.savefig("bundeslaender_todesfaelle.pdf")

# %%
all_cum_df[all_cum_df['state']=='Germany']

# %%
all_cum_df
# Out:
#      Meldedatum  AnzahlFall  AnzahlTodesfall  cumulative_cases  \
# 0    2020-01-28           2                0                 2
# 1    2020-01-29           2                0                 4
# 2    2020-01-31           3                0                 7
# 3    2020-02-03           1                0                 8
# 4    2020-02-04           2                0                10
# ..          ...         ...              ...               ...
# 320  2020-03-16        1776                2              8509
# 321  2020-03-17        2519                5             11028
# 322  2020-03-18        2689                7             13717
# 323  2020-03-19        1983                6             15700
# 324  2020-03-20         964                4             16664
#
#      cumulative_deaths days_since_50_cases days_since_first_death Bundesland  \
# 0                    0                 -37                    -37     Bayern
# 1                    0                 -36                    -36     Bayern
# 2                    0                 -34                    -34     Bayern
# 3                    0                 -31                    -31     Bayern
# 4                    0                 -30                    -30     Bayern
# ..                 ...                 ...                    ...        ...
# 320                 25                  17                     12    Germany
# 321                 30                  18                     13    Germany
# 322                 37                  19                     14    Germany
# 323                 43                  20                     15    Germany
# 324                 47                  21                     16    Germany
#
#      population  cumulative_deaths_normed  cumulative_cases_normed    state  \
# 0      13076721                  0.000000                 0.015294       BY
# 1      13076721                  0.000000                 0.030589       BY
# 2      13076721                  0.000000                 0.053530       BY
# 3      13076721                  0.000000                 0.061177       BY
# 4      13076721                  0.000000                 0.076472       BY
# ..          ...                       ...                      ...      ...
# 320    83019213                  0.030114                10.249435  Germany
# 321    83019213                  0.036136                13.283672  Germany
# 322    83019213                  0.044568                16.522681  Germany
# 323    83019213                  0.051795                18.911285  Germany
# 324    83019213                  0.056613                20.072462  Germany
#
#           date
# 0   2020-01-28
# 1   2020-01-29
# 2   2020-01-31
# 3   2020-02-03
# 4   2020-02-04
# ..         ...
# 320 2020-03-16
# 321 2020-03-17
# 322 2020-03-18
# 323 2020-03-19
# 324 2020-03-20
#
# [325 rows x 13 columns]

# %%
all_cum_df.columns
# Out:
# Index(['Meldedatum', 'AnzahlFall', 'AnzahlTodesfall', 'cumulative_cases',
#        'cumulative_deaths', 'days_since_50_cases', 'days_since_first_death',
#        'Bundesland', 'population', 'cumulative_deaths_normed',
#        'cumulative_cases_normed', 'state', 'date'],
#       dtype='object')

# %% [markdown]
# ### Bugfix

# %%
single_date = all_cum_df[all_cum_df['date']=='2020-03-19']
single_date[['state', 'cumulative_cases_normed']]

# %%
all_except_germany= single_date[single_date['state']!='Germany']
tot = single_date[single_date['state']=='Germany']

(all_except_germany['cumulative_cases_normed']*all_except_germany['population']).sum(), int(tot['cumulative_cases_normed']*tot['population'].iloc[0])

# %% [markdown]
# ## Hospitals

# %%
hosp = pd.read_csv('hospitals.csv')
hosp
# Out:
#               X          Y  OBJECTID  \
# 0      8.964586  50.041807      2001
# 1      9.935601  53.405574      2002
# 2     11.957312  51.193810      2003
# 3     13.789192  51.498525      2004
# 4      9.153941  49.233493      2005
# ...         ...        ...       ...
# 2849  12.648229  51.148162      1996
# 2850   7.617970  49.193025      1997
# 2851   8.671211  49.216840      1998
# 2852   8.018077  50.851575      1999
# 2853  11.081710  50.472312      2000
#
#                                                 name   amenity  \
# 0                      Asklepios Klinik Seligenstadt  hospital
# 1                 Ginsterhof Psychosomatische Klinik  hospital
# 2                                  Klinik Weißenfels  hospital
# 3                            Krankenhaus Lauchhammer  hospital
# 4                 SRH Gesundheitszentrum Bad Wimpfen  hospital
# ...                                              ...       ...
# 2849                                   Sachsenklinik  hospital
# 2850               Städtisches Krankenhaus Pirmasens  hospital
# 2851  Gotthard-Schettler-Klinik, Sigmund-Weil-Klinik  hospital
# 2852                   Ev. Jung-Stilling Krankenhaus  hospital
# 2853               Gesundheitszentrum "Am Rennsteig"  hospital
#
#           healthcare                              healthcare_speciality  \
# 0           hospital                                                NaN
# 1           hospital                                                NaN
# 2           hospital                                                NaN
# 3           hospital                                                NaN
# 4           hospital  internal;cardiology;orthopaedics;trauma;neurol...
# ...              ...                                                ...
# 2849  rehabilitation                                                NaN
# 2850        hospital                                                NaN
# 2851             NaN                                                NaN
# 2852             NaN                                                NaN
# 2853             NaN                                                NaN
#
#                                             operator operator_type  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2     Asklepios Kliniken Weißenfels-Hohenmölsen GmbH           NaN
# 3                        Klinikum Niederlausitz GmbH           NaN
# 4                                                NaN           NaN
# ...                                              ...           ...
# 2849                  Sachsenklinik Bad Lausick GmbH           NaN
# 2850         Städtisches Krankenhaus Pirmasens gGmbH           NaN
# 2851                                             NaN           NaN
# 2852                           Diakonie Südwestfalen           NaN
# 2853                AWO Kreisverband Sonneberg e. V.           NaN
#
#        contact_phone  ... religion emergency rooms  beds  capacity wheelchair  \
# 0                NaN  ...      NaN       yes   NaN   NaN       NaN        yes
# 1                NaN  ...      NaN       NaN   NaN   NaN       NaN        yes
# 2       +49 3443 400  ...      NaN       yes   NaN   NaN       NaN        yes
# 3       +49 3573 750  ...      NaN       yes   NaN   NaN       NaN        NaN
# 4                NaN  ...      NaN        no   NaN   NaN       NaN    limited
# ...              ...  ...      ...       ...   ...   ...       ...        ...
# 2849             NaN  ...      NaN       NaN   NaN   NaN       NaN        NaN
# 2850  +49 6331 714 0  ...      NaN       yes   NaN   NaN       NaN        yes
# 2851             NaN  ...      NaN        no   NaN   NaN       NaN    limited
# 2852             NaN  ...      NaN       yes   NaN   NaN       NaN        yes
# 2853             NaN  ...      NaN       NaN   NaN   NaN       NaN        NaN
#
#      wikidata wikipedia ORIG_FID                              GlobalID
# 0         NaN       NaN   9364.0  6b7e940f-eb18-4026-891d-c043f1e9698b
# 1         NaN       NaN   9391.0  6f4aa53a-1526-4e6f-bd08-cc06889c8881
# 2         NaN       NaN   9394.0  7e2e5dee-becb-4251-921b-42aa2868f4c8
# 3         NaN       NaN   9403.0  e8187a8f-8ab5-4544-942e-6d54227cbdb2
# 4         NaN       NaN   9412.0  81e538fa-215d-4cd1-aa8f-5f922d6ae21b
# ...       ...       ...      ...                                   ...
# 2849      NaN       NaN   9315.0  5145d2b7-3a6f-4605-84f9-40d8a31bcc3f
# 2850      NaN       NaN   9317.0  ee64ccc8-0d44-40e1-9366-fc035602e9b6
# 2851      NaN       NaN   9329.0  5fe2f0b6-360a-4d34-ad98-8770f4711a83
# 2852      NaN       NaN   9355.0  83fef599-9b64-4a5e-8025-5431e06eec4a
# 2853      NaN       NaN   9357.0  49db5b51-ddff-4aea-869e-1a33a1869e1b
#
# [2854 rows x 36 columns]

# %%
pd.notnull(hosp['beds']).sum()
# Out:
# 15

# %%
hosp[hosp['address_city']=='Bremen']
# Out:
#              X          Y  OBJECTID                                     name  \
# 130   8.940336  53.064179      2131                      Klinikum Bremen-Ost
# 159   8.745350  53.125936      2160                                    DIAKO
# 163   8.802845  53.069136      2164                  Rotes Kreuz Krankenhaus
# 170   8.824173  53.056400      2171                            Roland-Klinik
# 177   8.942529  53.075606      2178                Ameos Klinikum Dr. Heines
# 182   8.877509  53.079482      2183              Paracelsus Kurfürstenklinik
# 257   8.620861  53.174229      2258  Psychiatrisches Behandlungszentrum Nord
# 1789  8.594645  53.183159       936                     Klinikum Bremen-Nord
# 2352  8.841988  53.105208      1499     Augenklinik Universitätsallee Bremen
# 2508  8.834951  53.083384      1655                         St. Joseph-Stift
#
#        amenity healthcare healthcare_speciality  \
# 130   hospital   hospital                   NaN
# 159   hospital   hospital                   NaN
# 163   hospital   hospital                   NaN
# 170   hospital   hospital                   NaN
# 177   hospital   hospital                   NaN
# 182   hospital   hospital                   NaN
# 257   hospital   hospital            psychiatry
# 1789  hospital   hospital                   NaN
# 2352  hospital   hospital         ophthalmology
# 2508  hospital   hospital                   NaN
#
#                            operator operator_type  contact_phone  ...  \
# 130                             NaN           NaN            NaN  ...
# 159                             NaN           NaN            NaN  ...
# 163   Rotes Kreuz Krankenhaus gGmbH           NaN            NaN  ...
# 170                             NaN           NaN            NaN  ...
# 177                    AMEOS-Gruppe           NaN            NaN  ...
# 182                             NaN           NaN            NaN  ...
# 257                 Gesundheit Nord           NaN            NaN  ...
# 1789          Gesundheit Nord gGmbh           NaN            NaN  ...
# 2352                            NaN           NaN            NaN  ...
# 2508                            NaN           NaN  +49 421 347 0  ...
#
#      religion emergency rooms  beds  capacity wheelchair   wikidata  \
# 130       NaN       yes   NaN   NaN       NaN        yes   Q1774599
# 159       NaN       NaN   NaN   NaN       NaN        yes        NaN
# 163       NaN       yes   NaN   NaN       NaN        yes   Q2168511
# 170       NaN       NaN   NaN   NaN       NaN        NaN  Q15126321
# 177       NaN       NaN   NaN   NaN       NaN        yes        NaN
# 182       NaN        no   NaN   NaN       NaN        yes  Q65952688
# 257       NaN       NaN   NaN   NaN       NaN        NaN        NaN
# 1789      NaN       yes   NaN   NaN       NaN        yes   Q1774597
# 2352      NaN       NaN   NaN   NaN       NaN        NaN        NaN
# 2508      NaN       yes   NaN   NaN       NaN        yes   Q2316295
#
#                               wikipedia ORIG_FID  \
# 130              de:Klinikum Bremen-Ost  11305.0
# 159                                 NaN  11717.0
# 163   de:Rotes Kreuz Krankenhaus Bremen  11734.0
# 170                    de:Roland-Klinik  11768.0
# 177                de:Klinik Dr. Heines  11858.0
# 182                                 NaN  11898.0
# 257                                 NaN  13112.0
# 1789            de:Klinikum Bremen-Nord    999.0
# 2352                                NaN   4405.0
# 2508       de:St.-Joseph-Stift (Bremen)   5799.0
#
#                                   GlobalID
# 130   3f85ee04-6ba5-41a1-b94f-577446b40892
# 159   ec45ffce-2441-438d-9788-5b24384900ea
# 163   533210ce-97a5-493d-a752-5b54bad2ce2b
# 170   60d11789-7859-4b7d-95dc-6af625e01350
# 177   24eabd74-9acd-4540-8777-43aaf7645d70
# 182   dd747c10-52fa-4944-9641-98900212de31
# 257   ed92435f-50b0-4860-9ad1-002729499a28
# 1789  9463bcd9-685d-498f-95f8-c4986b7035ea
# 2352  9e758e63-49f0-4bdf-9e08-d7b9208517fd
# 2508  4894bcd7-eb97-438f-a2bc-46f707efbd36
#
# [10 rows x 36 columns]

# %%
other_hosp = pd.read_html("DIVI_Intensivregister.html")
other_hosp= other_hosp[0]
other_hosp
# Out:
#                                            Klinik­name  \
# 0    SANA Herz­zen­trum Dresden Innere Medizin und ...
# 1    AGAP­LE­SION DIAKONIE KLINIKEN KASSEL gGmbH An...
# 2    Agap­le­sion Diako­nie­kli­nikum Hamburg Inter...
# 3    Agap­le­sion Diako­nie­kli­nikum Roten­burg Pä...
# 4    Agap­le­sion Diako­nie­kli­nikum Roten­burg Ze...
# ..                                                 ...
# 474  West­küs­ten­kli­nikum Heide Medi­zi­ni­sche K...
# 475  Zeisig­wald­kli­niken Betha­nien Chem­nitz im ...
# 476  Zentral­klinik Bad Berka GmbH Zentrum für Anäs...
# 477  Zentrum für Intensiv-​ und Notfall­me­dizin, K...
# 478  Legende: Verfügbar Begrenzt Ausge­lastet ARDS-...
#
#                                                Kontakt Bundes­land  \
# 0         Kardio­lo­gi­sche Inten­siv­sta­tion Website          SN
# 1                           Inten­siv­sta­tion Website          HE
# 2                                           D1 Website          HH
# 3                                           17 Website          NI
# 4                                              Website          NI
# ..                                                 ...         ...
# 474   Inter­dis­zi­pli­näre Inten­siv­sta­tion Website          SH
# 475             Inter­dis­zi­pli­näre ITS/ IMC Website          SN
# 476                                                NaN          TH
# 477                    ZIN 10, ZIN 43, COBAZ 1 Website          SL
# 478  Legende: Verfügbar Begrenzt Ausge­lastet ARDS-...         NaN
#
#      ICU low care¹  ICU high care²  ECMO³             Stand
# 0              NaN             NaN    NaN  22.03.2020 09:21
# 1              NaN             NaN    NaN  21.03.2020 11:33
# 2              NaN             NaN    NaN  21.03.2020 13:13
# 3              NaN             NaN    NaN  18.03.2020 18:17
# 4              NaN             NaN    NaN  22.03.2020 10:18
# ..             ...             ...    ...               ...
# 474            NaN             NaN    NaN  21.03.2020 12:40
# 475            NaN             NaN    NaN  20.03.2020 10:56
# 476            NaN             NaN    NaN  20.03.2013 09:26
# 477            NaN             NaN    NaN  22.03.2020 10:05
# 478            NaN             NaN    NaN               NaN
#
# [479 rows x 7 columns]

# %% [markdown]
# #### From veronica

# %%
import json

# %%
with open('beds.json', 'r') as f:
    divi_beds = json.load(f)

# %%
beds_each_state = divi_beds['data'][0]['values']

# %%
divi_beds_df = pd.DataFrame(beds_each_state)
divi_beds_df.head()
# Out:
#    ARDS-Netzwerk  Aktualisiert von  Anzahl ECMO-Fälle pro Jahr  \
# 0              3            135673                         358
# 1              9            261768                         194
# 2              1             24691                           0
# 3             16            609720                         741
# 4              8            208097                         385
#
#    COVID-19 aktuell  COVID-19 beatmet  COVID-19 kumulativ  \
# 0                13                 5                   5
# 1                17                 5                   3
# 2                 2                 1                   0
# 3                65                31                  14
# 4                 7                 6                   2
#
#    COVID-19 verstorben  Gesamt aufgestellte Intensivbetten  ICU ECMO (belegt)  \
# 0                    0                                3352                  0
# 1                    0                                3811                  1
# 2                    0                                  18                  0
# 3                    5                                6618                  2
# 4                    0                                2193                  0
#
#    ICU ECMO (frei)  ...  icu_beds_future  icu_beds_now  icu_beds_now_rel  \
# 0               24  ...              177           164          0.000089
# 1               14  ...              336           303          0.000038
# 2                1  ...                6            16          0.000023
# 3               40  ...              586           631          0.000035
# 4               26  ...              242           244          0.000039
#
#          lat        lon  num_hospitals    osm_id  population     type  \
# 0  53.547292  10.010899             17   1067294     1841179  Feature
# 1  52.768287   9.800000             34  29433983     7982448  Feature
# 2  53.198115   8.741739              3    125118      682986  Feature
# 3  51.479839   7.561746             75  18559583    17932651  Feature
# 4  50.603381   9.031377             27   7107301     6265809  Feature
#
#                                             geometry
# 0  {'type': 'MultiPolygon', 'coordinates': [[[[10...
# 1  {'type': 'MultiPolygon', 'coordinates': [[[[8....
# 2  {'type': 'MultiPolygon', 'coordinates': [[[[8....
# 3  {'type': 'Polygon', 'coordinates': [[[8.666728...
# 4  {'type': 'Polygon', 'coordinates': [[[9.505598...
#
# [5 rows x 39 columns]

# %%
divi_beds_df.columns
# Out:
# Index(['ARDS-Netzwerk', 'Aktualisiert von', 'Anzahl ECMO-Fälle pro Jahr',
#        'COVID-19 aktuell', 'COVID-19 beatmet', 'COVID-19 kumulativ',
#        'COVID-19 verstorben', 'Gesamt aufgestellte Intensivbetten',
#        'ICU ECMO (belegt)', 'ICU ECMO (frei)',
#        'ICU ECMO care in 24 h (Anzahl)', 'ICU high care (belegt)',
#        'ICU high care (frei)', 'ICU high care in 24 h (Anzahl)',
#        'ICU low care (belegt)', 'ICU low care (frei)',
#        'ICU low care in 24 h (Anzahl)', 'ID', 'JSTATUS', 'PLZ', 'RS', 'RS_ALT',
#        'SHAPE_AREA', 'SHAPE_LENG', 'USE', 'Verwalter', 'ags', 'bundesland',
#        'covid_rel', 'icu_beds_future', 'icu_beds_now', 'icu_beds_now_rel',
#        'lat', 'lon', 'num_hospitals', 'osm_id', 'population', 'type',
#        'geometry'],
#       dtype='object')

# %%
divi_beds_df[[
    'bundesland', 'num_hospitals', 'Gesamt aufgestellte Intensivbetten'
]]
# Out:
#                 bundesland  num_hospitals  Gesamt aufgestellte Intensivbetten
# 0                  Hamburg             17                                3352
# 1            Niedersachsen             34                                3811
# 2                   Bremen              3                                  18
# 3      Nordrhein-Westfalen             75                                6618
# 4                   Hessen             27                                2193
# 5          Rheinland-Pfalz             36                                 918
# 6        Baden-Württemberg             44                                8361
# 7                   Bayern             71                                6572
# 8                 Saarland              7                                1657
# 9                   Berlin             32                                3422
# 10             Brandenburg             68                                2682
# 11  Mecklenburg-Vorpommern             61                                2387
# 12                 Sachsen             42                                1528
# 13          Sachsen-Anhalt             16                                1149
# 14               Thüringen              9                                 316
# 15      Schleswig-Holstein             42                                2483
