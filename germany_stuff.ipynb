# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Cases-in-each-state" data-toc-modified-id="Cases-in-each-state-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Cases in each state</a></div><div class="lev3 toc-item"><a href="#Download-population-densities" data-toc-modified-id="Download-population-densities-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Download population densities</a></div><div class="lev1 toc-item"><a href="#Deaths" data-toc-modified-id="Deaths-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Deaths</a></div><div class="lev2 toc-item"><a href="#get-all-the-states-in-a-single-DF" data-toc-modified-id="get-all-the-states-in-a-single-DF-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>get all the states in a single DF</a></div><div class="lev3 toc-item"><a href="#Bugfix" data-toc-modified-id="Bugfix-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Bugfix</a></div>

# %%
# %matplotlib inline
import matplotlib

matplotlib.rcParams['font.size'] = 15

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Main data source:
# https://npgeo-corona-npgeo-de.hub.arcgis.com/datasets/dd4580c810204019a7b8eb3e0b329dd6_0/data

# %%
url = "https://opendata.arcgis.com/datasets/dd4580c810204019a7b8eb3e0b329dd6_0.csv"

df = pd.read_csv(url)
df
# Out:
#       IdBundesland         Bundesland           Landkreis Altersgruppe  \
# 0               15     Sachsen-Anhalt        SK Magdeburg      A35-A59
# 1               15     Sachsen-Anhalt        SK Magdeburg      A35-A59
# 2               15     Sachsen-Anhalt        SK Magdeburg      A35-A59
# 3               15     Sachsen-Anhalt        SK Magdeburg      A60-A79
# 4               15     Sachsen-Anhalt        SK Magdeburg      A60-A79
# ...            ...                ...                 ...          ...
# 8227             8  Baden-Württemberg  LK Schwäbisch Hall      A15-A34
# 8228             8  Baden-Württemberg  LK Schwäbisch Hall      A15-A34
# 8229             8  Baden-Württemberg  LK Schwäbisch Hall      A15-A34
# 8230             8  Baden-Württemberg  LK Schwäbisch Hall      A15-A34
# 8231             8  Baden-Württemberg  LK Schwäbisch Hall      A15-A34
#
#      Geschlecht  AnzahlFall  AnzahlTodesfall  ObjectId  \
# 0             M           2                0    154936
# 1             W           1                0    154937
# 2             W           1                0    154938
# 3             M           1                0    154939
# 4             M           1                0    154940
# ...         ...         ...              ...       ...
# 8227          M           1                0    150931
# 8228          M           3                0    150932
# 8229          M           1                0    150933
# 8230          M           1                0    150934
# 8231          M           5                0    150935
#
#                     Meldedatum IdLandkreis
# 0     2020-03-18T00:00:00.000Z       15003
# 1     2020-03-12T00:00:00.000Z       15003
# 2     2020-03-17T00:00:00.000Z       15003
# 3     2020-03-10T00:00:00.000Z       15003
# 4     2020-03-19T00:00:00.000Z       15003
# ...                        ...         ...
# 8227  2020-03-13T00:00:00.000Z       08127
# 8228  2020-03-14T00:00:00.000Z       08127
# 8229  2020-03-15T00:00:00.000Z       08127
# 8230  2020-03-16T00:00:00.000Z       08127
# 8231  2020-03-17T00:00:00.000Z       08127
#
# [8232 rows x 10 columns]

# %%
df['Meldedatum'] = pd.to_datetime(df["Meldedatum"])

# %%
df.sort_values(by='Meldedatum')
# Out:
#       IdBundesland         Bundesland              Landkreis Altersgruppe  \
# 4700             9             Bayern    LK Landsberg a.Lech      A15-A34
# 4908             9             Bayern           LK Starnberg      A35-A59
# 4404             9             Bayern             SK München      A15-A34
# 4658             9             Bayern    LK Fürstenfeldbruck      A15-A34
# 4944             9             Bayern          LK Traunstein      A00-A04
# ...            ...                ...                    ...          ...
# 4808             9             Bayern             LK München      A60-A79
# 2608             8  Baden-Württemberg  LK Rhein-Neckar-Kreis      A60-A79
# 4813             9             Bayern             LK München      A60-A79
# 4771             9             Bayern             LK München      A15-A34
# 4115            10           Saarland        LK Sankt Wendel      A35-A59
#
#      Geschlecht  AnzahlFall  AnzahlTodesfall  ObjectId  \
# 4700          M           1                0    152404
# 4908          M           1                0    152612
# 4404          W           1                0    152108
# 4658          M           1                0    152362
# 4944          W           1                0    152648
# ...         ...         ...              ...       ...
# 4808          M           4                0    152512
# 2608          W           2                0    151312
# 4813          W           5                0    152517
# 4771  unbekannt           1                0    152475
# 4115          M           1                0    153819
#
#                     Meldedatum IdLandkreis
# 4700 2020-01-28 00:00:00+00:00       09181
# 4908 2020-01-28 00:00:00+00:00       09188
# 4404 2020-01-29 00:00:00+00:00       09162
# 4658 2020-01-29 00:00:00+00:00       09179
# 4944 2020-01-31 00:00:00+00:00       09189
# ...                        ...         ...
# 4808 2020-03-20 00:00:00+00:00       09184
# 2608 2020-03-20 00:00:00+00:00       08226
# 4813 2020-03-20 00:00:00+00:00       09184
# 4771 2020-03-20 00:00:00+00:00       09184
# 4115 2020-03-20 00:00:00+00:00       10046
#
# [8232 rows x 10 columns]

# %%
##

# %%
df['Altersgruppe'].unique()
# Out:
# array(['A35-A59', 'A60-A79', 'A80+', 'A15-A34', 'A05-A14', 'unbekannt',
#        'A00-A04'], dtype=object)

# %%
nie = df[df['Bundesland']=='Niedersachsen'][['Meldedatum', 'AnzahlFall']]
nie
# Out:
#                     Meldedatum  AnzahlFall
# 1566 2020-03-05 00:00:00+00:00           1
# 1567 2020-03-11 00:00:00+00:00           1
# 1568 2020-03-14 00:00:00+00:00           1
# 1569 2020-03-18 00:00:00+00:00           1
# 1570 2020-03-14 00:00:00+00:00           1
# ...                        ...         ...
# 2217 2020-03-18 00:00:00+00:00           1
# 2218 2020-03-19 00:00:00+00:00           1
# 2219 2020-03-11 00:00:00+00:00           1
# 2220 2020-03-14 00:00:00+00:00           2
# 2221 2020-03-18 00:00:00+00:00           1
#
# [656 rows x 2 columns]

# %%
nie['date'] = nie['Meldedatum'].apply(lambda x:x.date())
nie
# Out:
#                     Meldedatum  AnzahlFall        date
# 1566 2020-03-05 00:00:00+00:00           1  2020-03-05
# 1567 2020-03-11 00:00:00+00:00           1  2020-03-11
# 1568 2020-03-14 00:00:00+00:00           1  2020-03-14
# 1569 2020-03-18 00:00:00+00:00           1  2020-03-18
# 1570 2020-03-14 00:00:00+00:00           1  2020-03-14
# ...                        ...         ...         ...
# 2217 2020-03-18 00:00:00+00:00           1  2020-03-18
# 2218 2020-03-19 00:00:00+00:00           1  2020-03-19
# 2219 2020-03-11 00:00:00+00:00           1  2020-03-11
# 2220 2020-03-14 00:00:00+00:00           2  2020-03-14
# 2221 2020-03-18 00:00:00+00:00           1  2020-03-18
#
# [656 rows x 3 columns]

# %%
case_ts = nie[['date', 'AnzahlFall']].groupby('date').agg('sum')
case_ts['cumulative'] = case_ts['AnzahlFall'].cumsum()
case_ts
# Out:
#             AnzahlFall  cumulative
# date
# 2020-02-04           1           1
# 2020-03-01           1           2
# 2020-03-02           1           3
# 2020-03-03           6           9
# 2020-03-04           3          12
# 2020-03-05           5          17
# 2020-03-06           8          25
# 2020-03-07           7          32
# 2020-03-08           3          35
# 2020-03-09          16          51
# 2020-03-10          34          85
# 2020-03-11          52         137
# 2020-03-12          65         202
# 2020-03-13          81         283
# 2020-03-14          57         340
# 2020-03-15          48         388
# 2020-03-16         126         514
# 2020-03-17         128         642
# 2020-03-18         187         829
# 2020-03-19         139         968
# 2020-03-20          55        1023

# %%
import seaborn as sns

# %%
import numpy as np

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,4))

case_ts['cumulative'].plot(ax=ax1)

thres = 50
thres_crossing_date = case_ts[case_ts['cumulative'] > 50].iloc[0].name
case_ts['day_since_thres'] = case_ts.index - thres_crossing_date

sns.lineplot(x='day_since_thres', y='cumulative', estimator=None, data=case_ts)
day_min = 0
day_max = case_ts['day_since_thres'].max()/pd.Timedelta(days=1)

ax2.set_xlim(0, day_max*24*3600*1000)

xtick_days = np.arange(0, day_max, 5)
xticks = [day*24*3600*1000 for day in xtick_days]
xticklabels = [str(d) for d in xtick_days]

ax2.set_xticks(xticks)
ax2.set_xticklabels(xticklabels)
# Out:
# [Text(0, 0, '0.0'), Text(0, 0, '5.0'), Text(0, 0, '10.0')]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,4))

case_ts['cumulative'].plot(ax=ax1)
ax1.tick_params(axis='x', labelrotation=45)


thres = 50
thres_crossing_date = case_ts[case_ts['cumulative'] > 50].iloc[0].name
case_ts['day_since_thres'] = (case_ts.index - thres_crossing_date)/pd.Timedelta(days=1)

sns.lineplot(x='day_since_thres', y='cumulative', estimator=None, data=case_ts, ax=ax2)
xmin, xmax = ax2.get_xlim()
ax2.set_xlim(0, xmax)
# Out:
# (0.0, 13.25)

# %% [markdown]
# # Cases in each state

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18,7))

day_max = 0

for bundesland in df['Bundesland'].unique():
    df_state = df[df['Bundesland']==bundesland][['Meldedatum', 'AnzahlFall']]
    df_state['date'] = df_state['Meldedatum'].apply(lambda x:x.date())
    case_ts = df_state[['date', 'AnzahlFall']].groupby('date').agg('sum')
    case_ts['cumulative'] = case_ts['AnzahlFall'].cumsum()

    case_ts['cumulative'].plot(ax=ax1, label=bundesland[:4])
    ax1.tick_params(axis='x', labelrotation=45)


    thres = 50
    if len(case_ts[case_ts['cumulative'] > 50]) == 0:
        continue
    thres_crossing_date = case_ts[case_ts['cumulative'] > 50].iloc[0].name
    case_ts['day_since_thres'] = (case_ts.index - thres_crossing_date)/pd.Timedelta(days=1)

    sns.lineplot(x='day_since_thres', y='cumulative', estimator=None, data=case_ts, ax=ax2, label=bundesland[:4])
    
ax2.set_xlim(0, ax2.get_xlim()[1])
ax1.legend()
ax2.legend()

ax2.set_xlabel("days since 50 cases")
ax2.set_ylabel("cases")

ax2.set_yscale('log')
ax1.set_yscale('log')

# %% [markdown]
# ### Download population densities

# %%
# !pip install bs4
# Out:
# Requirement already satisfied: bs4 in ./venv/lib/python3.6/site-packages
# Requirement already satisfied: beautifulsoup4 in ./venv/lib/python3.6/site-packages (from bs4)
# Requirement already satisfied: soupsieve>=1.2 in ./venv/lib/python3.6/site-packages (from beautifulsoup4->bs4)

# %%
import pandas as pd

# %%
tables = pd.read_html("https://de.wikipedia.org/wiki/Liste_der_deutschen_Bundesl%C3%A4nder_nach_Bev%C3%B6lkerung", thousands='.')
tables[0]
# Out:
#                 Bundesland        1960        1970        1980      1990  \
# 0        Baden-Württemberg   7726859.0   8953607.0   9258947.0   9822027
# 1                   Bayern   9494939.0  10561110.0  10928151.0  11448823
# 2                Berlin[1]   2202241.0   2115311.0   1896230.0   3433695
# 3              Brandenburg         NaN         NaN         NaN   2578312
# 4                   Bremen    704287.0    735452.0    693846.0    681665
# 5                  Hamburg   1836958.0   1793640.0   1645095.0   1652363
# 6                   Hessen   4783352.0   5424529.0   5601031.0   5763310
# 7   Mecklenburg-Vorpommern         NaN         NaN         NaN   1923959
# 8            Niedersachsen   6576137.0   7121824.0   7256386.0   7387245
# 9      Nordrhein-Westfalen  15852476.0  17004851.0  17058193.0  17349651
# 10         Rheinland-Pfalz   3411170.0   3658932.0   3642482.0   3763510
# 11                Saarland   1060493.0   1121300.0   1066299.0   1072963
# 12                 Sachsen         NaN         NaN         NaN   4764301
# 13          Sachsen-Anhalt         NaN         NaN         NaN   2873957
# 14      Schleswig-Holstein   2309409.0   2510608.0   2611285.0   2626127
# 15               Thüringen         NaN         NaN         NaN   2611319
# 16          Deutschland[2]  55958321.0  61001164.0  61657945.0  79753227
#
#         2000      2010      2015      2018
# 0   10524415  10753880  10879618  11069533
# 1   12230255  12538696  12843514  13076721
# 2    3382169   3460725   3520031   3644826
# 3    2601962   2503273   2484826   2511917
# 4     660225    660706    671489    682986
# 5    1715392   1786448   1787408   1841179
# 6    6068129   6067021   6176172   6265809
# 7    1775703   1642327   1612362   1609675
# 8    7926193   7918293   7926599   7982448
# 9   18009865  17845154  17865516  17932651
# 10   4034557   4003745   4052803   4084844
# 11   1068703   1017567    995597    990509
# 12   4425581   4149477   4084851   4077937
# 13   2615375   2335006   2245470   2208321
# 14   2789761   2834259   2858714   2896712
# 15   2431255   2235025   2170714   2143145
# 16  82259540  81751602  82175684  83019213

# %%
population_states = tables[0][['Bundesland', '2018']]
population_states.head()
# Out:
#           Bundesland      2018
# 0  Baden-Württemberg  11069533
# 1             Bayern  13076721
# 2          Berlin[1]   3644826
# 3        Brandenburg   2511917
# 4             Bremen    682986

# %%
population_states.loc[2, 'Bundesland'] = 'Berlin'
population_states.loc[16, 'Bundesland'] = 'Germany'
# Out:
# /home/dmanik/covid-19/venv/lib/python3.6/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
population_states
# Out:
#                 Bundesland      2018
# 0        Baden-Württemberg  11069533
# 1                   Bayern  13076721
# 2                   Berlin   3644826
# 3              Brandenburg   2511917
# 4                   Bremen    682986
# 5                  Hamburg   1841179
# 6                   Hessen   6265809
# 7   Mecklenburg-Vorpommern   1609675
# 8            Niedersachsen   7982448
# 9      Nordrhein-Westfalen  17932651
# 10         Rheinland-Pfalz   4084844
# 11                Saarland    990509
# 12                 Sachsen   4077937
# 13          Sachsen-Anhalt   2208321
# 14      Schleswig-Holstein   2896712
# 15               Thüringen   2143145
# 16                 Germany  83019213

# %%
population_states
# Out:
#                 Bundesland      2018
# 0        Baden-Württemberg  11069533
# 1                   Bayern  13076721
# 2                   Berlin   3644826
# 3              Brandenburg   2511917
# 4                   Bremen    682986
# 5                  Hamburg   1841179
# 6                   Hessen   6265809
# 7   Mecklenburg-Vorpommern   1609675
# 8            Niedersachsen   7982448
# 9      Nordrhein-Westfalen  17932651
# 10         Rheinland-Pfalz   4084844
# 11                Saarland    990509
# 12                 Sachsen   4077937
# 13          Sachsen-Anhalt   2208321
# 14      Schleswig-Holstein   2896712
# 15               Thüringen   2143145
# 16                 Germany  83019213

# %%
day_max = 0

with sns.color_palette("husl"):
    fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18,7))
    
    case_thres = 50

    for bundesland in list(df['Bundesland'].unique()) + ['Germany']:
        # get population
        try:
            pop = population_states[population_states['Bundesland']==bundesland].values[0,1]
        except:
            print(f"Population for {bundesland} not found")
            continue
                    
        if bundesland == 'Germany':
            label='Germany'
            df_state = df[['Meldedatum', 'AnzahlFall']]
        else:
            df_state = df[df['Bundesland']==bundesland][['Meldedatum', 'AnzahlFall']]
            label = bundesland[:4]
            
        df_state['date'] = df_state['Meldedatum'].apply(lambda x:x.date())
        df_state.sort_values(by='date')

        case_ts = df_state[['date', 'AnzahlFall']].groupby('date').agg('sum')
        case_ts['cumulative'] = case_ts['AnzahlFall'].cumsum()
        case_ts['cumulative_normed'] = case_ts['cumulative']/pop*100000

        case_ts['cumulative_normed'].plot(ax=ax1, label=label)
        ax1.tick_params(axis='x', labelrotation=45)


        if len(case_ts[case_ts['cumulative'] > case_thres]) == 0:
            continue
        thres_crossing_date = case_ts[case_ts['cumulative'] > case_thres].iloc[0].name
        case_ts['day_since_thres'] = (case_ts.index - thres_crossing_date)/pd.Timedelta(days=1)

        sns.lineplot(x='day_since_thres', y='cumulative_normed', estimator=None, data=case_ts, ax=ax2, label=label, markers=True, dashes=True)
        
    ax2.set_xlim(0, ax2.get_xlim()[1])
    ax1.legend(fontsize=15, ncol=2)
    ax2.legend(fontsize=15, ncol=2)

    ax2.set_xlabel(f"days since {case_thres} cases reported")
    ax2.set_ylabel("cases/100000 inhabitants")

    ax2.set_yscale('log')
    ax1.set_yscale('log')

fig.tight_layout()

fig.savefig("bundeslaender.pdf")
# Out:
# Population for -nicht erhoben- not found
# /home/dmanik/covid-19/venv/lib/python3.6/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # Deaths

# %%
day_max = 0

with sns.color_palette("husl"):
    fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18,7))
    
    for bundesland in list(df['Bundesland'].unique()) + ['Germany']:
        # get population
        try:
            pop = population_states[population_states['Bundesland']==bundesland].values[0,1]
        except:
            print(f"Population for {bundesland} not found")
            continue
                    
        if bundesland == 'Germany':
            label='Germany'
            df_state = df[['Meldedatum', 'AnzahlTodesfall']]
        else:
            df_state = df[df['Bundesland']==bundesland][['Meldedatum', 'AnzahlTodesfall']]
            label = bundesland[:4]
            
        df_state['date'] = df_state['Meldedatum'].apply(lambda x:x.date())
        df_state.sort_values(by='date')
        case_ts = df_state[['date', 'AnzahlTodesfall']].groupby('date').agg('sum')
        case_ts['cumulative'] = case_ts['AnzahlTodesfall'].cumsum()
        case_ts['cumulative_normed'] = case_ts['cumulative']/pop*100000

        case_ts['cumulative_normed'].plot(ax=ax1, label=label)
        ax1.tick_params(axis='x', labelrotation=45)


        if len(case_ts[case_ts['cumulative'] > 0]) == 0:
            print(f"No death in {bundesland}")
            continue
        thres_crossing_date = case_ts[case_ts['cumulative'] > 0].iloc[0].name
        case_ts['day_since_thres'] = (case_ts.index - thres_crossing_date)/pd.Timedelta(days=1)

        sns.lineplot(x='day_since_thres', y='cumulative_normed', estimator=None, data=case_ts, ax=ax2, label=label, markers=True, dashes=True)
        
    ax2.set_xlim(0, ax2.get_xlim()[1])
    ax1.legend(fontsize=15, ncol=2)
    ax2.legend(fontsize=15, ncol=2)

    ax2.set_xlabel(f"days since first death")
    ax2.set_ylabel("deaths/100000 inhabitants")

    ax2.set_yscale('log')
    ax1.set_yscale('log')
    ax1.xaxis.set_tick_params(rotation=45)
fig.tight_layout()

#fig.savefig("bundeslaender.pdf")
# Out:
# No death in Thüringen
# No death in Bremen
# Population for -nicht erhoben- not found
# No death in Hamburg
# No death in Niedersachsen
# No death in Saarland
# No death in Brandenburg
# No death in Mecklenburg-Vorpommern
# No death in Sachsen
# /home/dmanik/covid-19/venv/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## get all the states in a single DF

# %%
 df_state = df[df['Bundesland']==bundesland][['Meldedatum', 'AnzahlFall']]
            label = bundesland[:4]
            
df_state['date'] = df_state['Meldedatum'].apply(lambda x:x.date())
df_state.sort_values(by='date')

# %%
narrow_df = df[['Bundesland', 'AnzahlFall', 'AnzahlTodesfall', 'Meldedatum']]
narrow_df['Meldedatum'] = narrow_df['Meldedatum'].apply(lambda x:x.date())
narrow_df
# Out:
# /home/dmanik/covid-19/venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              Bundesland  AnzahlFall  AnzahlTodesfall  Meldedatum
# 0        Sachsen-Anhalt           2                0  2020-03-18
# 1        Sachsen-Anhalt           1                0  2020-03-12
# 2        Sachsen-Anhalt           1                0  2020-03-17
# 3        Sachsen-Anhalt           1                0  2020-03-10
# 4        Sachsen-Anhalt           1                0  2020-03-19
# ...                 ...         ...              ...         ...
# 8227  Baden-Württemberg           1                0  2020-03-13
# 8228  Baden-Württemberg           3                0  2020-03-14
# 8229  Baden-Württemberg           1                0  2020-03-15
# 8230  Baden-Württemberg           1                0  2020-03-16
# 8231  Baden-Württemberg           5                0  2020-03-17
#
# [8232 rows x 4 columns]

# %%
narrow_df.sort_values(by='Meldedatum', inplace=True)
cumsum_dfs = []

for bundesland in list(narrow_df['Bundesland'].unique())+['Germany']:
    if bundesland == 'Germany':
        sel = narrow_df
    else:
        sel = narrow_df[narrow_df['Bundesland']==bundesland]
    sel = sel[['Meldedatum','AnzahlFall', 'AnzahlTodesfall']].groupby('Meldedatum').agg('sum')
    sel = sel.sort_values(by='Meldedatum')
    sel['cumulative_cases'] = sel['AnzahlFall'].cumsum()
    sel['cumulative_deaths'] = sel['AnzahlTodesfall'].cumsum()
    
    if len(sel[sel['cumulative_cases'] > 50]) > 0:
        first_case_date = sel[sel['cumulative_cases'] > 50].iloc[0].name
        sel['days_since_50_cases'] = (sel.index - first_case_date)/pd.Timedelta(days=1)
    else:
        sel['days_since_50_cases'] = None
    
    if len(sel[sel['cumulative_deaths'] > 0]) > 0:
        first_death_date = sel[sel['cumulative_deaths'] > 0].iloc[0].name
        sel['days_since_first_death'] = (sel.index - first_death_date)/pd.Timedelta(days=1)
    else:
        sel['days_since_first_death'] = None
    sel['Bundesland'] = bundesland
    
    cumsum_dfs.append(sel.reset_index())

all_cum_df = pd.concat(cumsum_dfs)
all_cum_df
# Out:
# /home/dmanik/covid-19/venv/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     Meldedatum  AnzahlFall  AnzahlTodesfall  cumulative_cases  \
# 0   2020-01-28           2                0                 2
# 1   2020-01-29           2                0                 4
# 2   2020-01-31           3                0                 7
# 3   2020-02-03           1                0                 8
# 4   2020-02-04           2                0                10
# ..         ...         ...              ...               ...
# 29  2020-03-16        1776                2              8509
# 30  2020-03-17        2519                5             11028
# 31  2020-03-18        2689                7             13717
# 32  2020-03-19        1983                6             15700
# 33  2020-03-20         964                4             16664
#
#     cumulative_deaths days_since_50_cases days_since_first_death Bundesland
# 0                   0                 -37                    -37     Bayern
# 1                   0                 -36                    -36     Bayern
# 2                   0                 -34                    -34     Bayern
# 3                   0                 -31                    -31     Bayern
# 4                   0                 -30                    -30     Bayern
# ..                ...                 ...                    ...        ...
# 29                 25                  17                     12    Germany
# 30                 30                  18                     13    Germany
# 31                 37                  19                     14    Germany
# 32                 43                  20                     15    Germany
# 33                 47                  21                     16    Germany
#
# [327 rows x 8 columns]

# %%
all_cum_df[all_cum_df['cumulative_deaths']>0].iloc[0]
# Out:
# Meldedatum                           2020-03-05
# AnzahlFall                                   22
# AnzahlTodesfall                               1
# cumulative_cases                             67
# cumulative_deaths                             1
# days_since_50_cases                           0
# days_since_first_death                        0
# Bundesland                               Bayern
# population                             13076721
# cumulative_deaths_normed             0.00764718
# cumulative_cases_normed                0.512361
# state                                        BY
# date                        2020-03-05 00:00:00
# Name: 16, dtype: object

# %%
# !date
# Out:
# Sat Mar 21 20:56:27 CET 2020

# %%
21-5
# Out:
# 16

# %%
all_cum_df = all_cum_df.merge(population_states, left_on='Bundesland', right_on='Bundesland')
all_cum_df.rename({'2018': 'population'}, axis='columns', inplace=True)
all_cum_df
# Out:
#      Meldedatum  AnzahlFall  AnzahlTodesfall  cumulative_cases  \
# 0    2020-01-28           2                0                 2
# 1    2020-01-29           2                0                 4
# 2    2020-01-31           3                0                 7
# 3    2020-02-03           1                0                 8
# 4    2020-02-04           2                0                10
# ..          ...         ...              ...               ...
# 320  2020-03-16        1776                2              8509
# 321  2020-03-17        2519                5             11028
# 322  2020-03-18        2689                7             13717
# 323  2020-03-19        1983                6             15700
# 324  2020-03-20         964                4             16664
#
#      cumulative_deaths days_since_50_cases days_since_first_death Bundesland  \
# 0                    0                 -37                    -37     Bayern
# 1                    0                 -36                    -36     Bayern
# 2                    0                 -34                    -34     Bayern
# 3                    0                 -31                    -31     Bayern
# 4                    0                 -30                    -30     Bayern
# ..                 ...                 ...                    ...        ...
# 320                 25                  17                     12    Germany
# 321                 30                  18                     13    Germany
# 322                 37                  19                     14    Germany
# 323                 43                  20                     15    Germany
# 324                 47                  21                     16    Germany
#
#      population
# 0      13076721
# 1      13076721
# 2      13076721
# 3      13076721
# 4      13076721
# ..          ...
# 320    83019213
# 321    83019213
# 322    83019213
# 323    83019213
# 324    83019213
#
# [325 rows x 9 columns]

# %%
all_cum_df['cumulative_deaths_normed'] = all_cum_df['cumulative_deaths']*100000/all_cum_df['population']
all_cum_df['cumulative_cases_normed'] = all_cum_df['cumulative_cases']*100000/all_cum_df['population']

# %%
german_state_abbrs = {
'Baden-Württemberg': 'BW',
'Bayern': 'BY',
'Berlin': 'BE',
'Brandenburg': 'BB',
'Bremen': 'HB',
'Hamburg': 'HH',
'Hessen': 'HE',
'Niedersachsen': 'NI',
'Mecklenburg-Vorpommern': 'MV',
'Nordrhein-Westfalen': 'NW',
'Rheinland-Pfalz': 'RP',
'Saarland': 'SL',
'Sachsen': 'SN',
'Sachsen-Anhalt': 'ST',
'Schleswig-Holstein': 'SH',
'Thüringen': 'TH',
}

# %%
all_cum_df['state'] = all_cum_df['Bundesland'].apply(lambda x:german_state_abbrs[x] if x!='Germany' else 'Germany')
all_cum_df['date'] = all_cum_df['Meldedatum'].apply(lambda x:pd.Timestamp(x))

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18,6))

sns.lineplot(data=all_cum_df, x='Meldedatum', y='cumulative_cases_normed', hue='state', ax=ax1, ci=None)
sns.lineplot(data=all_cum_df, x='days_since_50_cases', y='cumulative_cases_normed', hue='state', ax=ax2, ci=None)

#ax1.set_xlim(0, ax1.get_xlim()[1])
ax2.set_xlim(0, ax2.get_xlim()[1])
ax1.legend(fontsize=10, ncol=2)
ax2.legend(fontsize=10, ncol=2)

ax1.set_ylabel("cases/100000 inhabitants")
ax2.set_xlabel(f"days since 50 cases")
ax2.set_ylabel("cases/100000 inhabitants")

ax1.xaxis.set_tick_params(rotation=45)

ax2.set_yscale('log')
ax1.set_yscale('log')

fig.tight_layout()
fig.savefig("bundeslaender_faelle.pdf")

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18,6))

sns.lineplot(data=all_cum_df, x='Meldedatum', y='cumulative_deaths_normed', hue='state', ax=ax1, ci=None)
sns.lineplot(data=all_cum_df, x='days_since_first_death', y='cumulative_deaths_normed', hue='state', ax=ax2, ci=None)


#ax1.set_xlim(0, ax1.get_xlim()[1])
ax2.set_xlim(0, ax2.get_xlim()[1])
ax1.legend(fontsize=10, ncol=2)
ax2.legend(fontsize=10, ncol=2)


ax1.set_ylabel("deaths/100000 inhabitants")

ax2.set_xlabel(f"days since first death")
ax2.set_ylabel("deaths/100000 inhabitants")

ax1.xaxis.set_tick_params(rotation=45)

ax2.set_yscale('log')
ax1.set_yscale('log')

fig.tight_layout()
fig.savefig("bundeslaender_todesfaelle.pdf")

# %%
all_cum_df[all_cum_df['state']=='Germany']
# Out:
#      Meldedatum  AnzahlFall  AnzahlTodesfall  cumulative_cases  \
# 291  2020-01-28           2                0                 2
# 292  2020-01-29           2                0                 4
# 293  2020-01-31           3                0                 7
# 294  2020-02-03           1                0                 8
# 295  2020-02-04           3                0                11
# 296  2020-02-06           1                0                12
# 297  2020-02-07           1                0                13
# 298  2020-02-11           2                0                15
# 299  2020-02-12           1                0                16
# 300  2020-02-25           2                0                18
# 301  2020-02-26           8                0                26
# 302  2020-02-27          21                0                47
# 303  2020-02-28          41                0                88
# 304  2020-02-29          20                0               108
# 305  2020-03-01          33                0               141
# 306  2020-03-02          40                0               181
# 307  2020-03-03          65                0               246
# 308  2020-03-04         140                1               386
# 309  2020-03-05         171                1               557
# 310  2020-03-06         162                1               719
# 311  2020-03-07         132                2               851
# 312  2020-03-08          83                0               934
# 313  2020-03-09         315                1              1249
# 314  2020-03-10         545                2              1794
# 315  2020-03-11         690                3              2484
# 316  2020-03-12         916                4              3400
# 317  2020-03-13        1317                4              4717
# 318  2020-03-14        1179                2              5896
# 319  2020-03-15         837                2              6733
# 320  2020-03-16        1776                2              8509
# 321  2020-03-17        2519                5             11028
# 322  2020-03-18        2689                7             13717
# 323  2020-03-19        1983                6             15700
# 324  2020-03-20         964                4             16664
#
#      cumulative_deaths days_since_50_cases days_since_first_death Bundesland  \
# 291                  0                 -31                    -36    Germany
# 292                  0                 -30                    -35    Germany
# 293                  0                 -28                    -33    Germany
# 294                  0                 -25                    -30    Germany
# 295                  0                 -24                    -29    Germany
# 296                  0                 -22                    -27    Germany
# 297                  0                 -21                    -26    Germany
# 298                  0                 -17                    -22    Germany
# 299                  0                 -16                    -21    Germany
# 300                  0                  -3                     -8    Germany
# 301                  0                  -2                     -7    Germany
# 302                  0                  -1                     -6    Germany
# 303                  0                   0                     -5    Germany
# 304                  0                   1                     -4    Germany
# 305                  0                   2                     -3    Germany
# 306                  0                   3                     -2    Germany
# 307                  0                   4                     -1    Germany
# 308                  1                   5                      0    Germany
# 309                  2                   6                      1    Germany
# 310                  3                   7                      2    Germany
# 311                  5                   8                      3    Germany
# 312                  5                   9                      4    Germany
# 313                  6                  10                      5    Germany
# 314                  8                  11                      6    Germany
# 315                 11                  12                      7    Germany
# 316                 15                  13                      8    Germany
# 317                 19                  14                      9    Germany
# 318                 21                  15                     10    Germany
# 319                 23                  16                     11    Germany
# 320                 25                  17                     12    Germany
# 321                 30                  18                     13    Germany
# 322                 37                  19                     14    Germany
# 323                 43                  20                     15    Germany
# 324                 47                  21                     16    Germany
#
#      population  cumulative_deaths_normed  cumulative_cases_normed    state  \
# 291    83019213                  0.000000                 0.002409  Germany
# 292    83019213                  0.000000                 0.004818  Germany
# 293    83019213                  0.000000                 0.008432  Germany
# 294    83019213                  0.000000                 0.009636  Germany
# 295    83019213                  0.000000                 0.013250  Germany
# 296    83019213                  0.000000                 0.014454  Germany
# 297    83019213                  0.000000                 0.015659  Germany
# 298    83019213                  0.000000                 0.018068  Germany
# 299    83019213                  0.000000                 0.019273  Germany
# 300    83019213                  0.000000                 0.021682  Germany
# 301    83019213                  0.000000                 0.031318  Germany
# 302    83019213                  0.000000                 0.056613  Germany
# 303    83019213                  0.000000                 0.106000  Germany
# 304    83019213                  0.000000                 0.130090  Germany
# 305    83019213                  0.000000                 0.169840  Germany
# 306    83019213                  0.000000                 0.218022  Germany
# 307    83019213                  0.000000                 0.296317  Germany
# 308    83019213                  0.001205                 0.464953  Germany
# 309    83019213                  0.002409                 0.670929  Germany
# 310    83019213                  0.003614                 0.866065  Germany
# 311    83019213                  0.006023                 1.025064  Germany
# 312    83019213                  0.006023                 1.125041  Germany
# 313    83019213                  0.007227                 1.504471  Germany
# 314    83019213                  0.009636                 2.160946  Germany
# 315    83019213                  0.013250                 2.992078  Germany
# 316    83019213                  0.018068                 4.095438  Germany
# 317    83019213                  0.022886                 5.681817  Germany
# 318    83019213                  0.025295                 7.101970  Germany
# 319    83019213                  0.027704                 8.110171  Germany
# 320    83019213                  0.030114                10.249435  Germany
# 321    83019213                  0.036136                13.283672  Germany
# 322    83019213                  0.044568                16.522681  Germany
# 323    83019213                  0.051795                18.911285  Germany
# 324    83019213                  0.056613                20.072462  Germany
#
#           date
# 291 2020-01-28
# 292 2020-01-29
# 293 2020-01-31
# 294 2020-02-03
# 295 2020-02-04
# 296 2020-02-06
# 297 2020-02-07
# 298 2020-02-11
# 299 2020-02-12
# 300 2020-02-25
# 301 2020-02-26
# 302 2020-02-27
# 303 2020-02-28
# 304 2020-02-29
# 305 2020-03-01
# 306 2020-03-02
# 307 2020-03-03
# 308 2020-03-04
# 309 2020-03-05
# 310 2020-03-06
# 311 2020-03-07
# 312 2020-03-08
# 313 2020-03-09
# 314 2020-03-10
# 315 2020-03-11
# 316 2020-03-12
# 317 2020-03-13
# 318 2020-03-14
# 319 2020-03-15
# 320 2020-03-16
# 321 2020-03-17
# 322 2020-03-18
# 323 2020-03-19
# 324 2020-03-20

# %% [markdown]
# ### Bugfix

# %%
single_date = all_cum_df[all_cum_df['date']=='2020-03-19']
single_date[['state', 'cumulative_cases_normed']]
# Out:
#        state  cumulative_cases_normed
# 30        BY                20.150311
# 51        NI                12.126606
# 75        BW                32.178413
# 99        NW                19.746104
# 119       RP                21.273762
# 139       HE                15.049932
# 158       SH                 9.424479
# 177       HH                31.881745
# 191       BB                 9.833127
# 206       HB                17.569906
# 222       SN                12.874157
# 240       BE                21.235582
# 252       TH                 7.092381
# 267       MV                 9.815646
# 280       SL                15.850436
# 290       ST                 8.513255
# 323  Germany                18.911285

# %%
all_except_germany= single_date[single_date['state']!='Germany']
tot = single_date[single_date['state']=='Germany']

(all_except_germany['cumulative_cases_normed']*all_except_germany['population']).sum(), int(tot['cumulative_cases_normed']*tot['population'].iloc[0])
# Out:
# (1569900000.0, 1570000000)
